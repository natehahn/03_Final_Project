# %%
# Add the Pandas dependency.
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Granger\Desktop\Data Tables_03_Final_Project\CO2.csv')
print(df)
# Out:
#         country_code            area  year_pc  category_code  \
# 0                  0     Afghanistan     2000              1
# 1                  0     Afghanistan     2000              3
# 2                  0     Afghanistan     2000              4
# 3                  0     Afghanistan     2000              4
# 4                  0     Afghanistan     2000              4
# ...              ...             ...      ...            ...
# 328008           901  Sudan (former)     2011             35
# 328009           901  Sudan (former)     2011             39
# 328010           901  Sudan (former)     2011             39
# 328011           901  Sudan (former)     2011             41
# 328012           901  Sudan (former)     2011             42
#
#        food_product_categories  production  total_kgs_CO2
# 0                       Apples    40540.06   5.878309e+04
# 1                Barley (Beer)    74000.00   1.724200e+05
# ...

# %%
grouped_df = df.groupby(["country_code", "area", "year_pc", "category_code", "food_product_categories"])
grouped_df.sum()
# Out:
#                                                                            production  \
# country_code area           year_pc category_code food_product_categories
# 0            Afghanistan    2000    1             Apples                     40540.06
#                                     3             Barley (Beer)              74000.00
#                                     4             Beef (beef herd)          151200.00
#                                     6             Beet Sugar                  1000.00
#                                     7             Berries & Grapes          400206.33
# ...                                                                               ...
# 901          Sudan (former) 2011    34            Rice                       25000.00
#                                     35            Root Vegetables           383153.00
#                                     39            Sunflower Oil             161008.12
# ...

# %%
final_grouped_df = grouped_df.sum()
final_grouped_df.to_csv(r'C:\Users\Granger\Desktop\Data Tables_03_Final_Project\CO2final.csv')
